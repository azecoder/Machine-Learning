# %% [markdown]
# <a href="https://colab.research.google.com/github/azecoder/ML/blob/master/SVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("initialize")

# trainDB = pd.read_csv("")
# Out:
# initialize
